# %% [markdown]
# Práctica 10

# %%
import pandas as pd

# Creamos el dataframe
df = pd.read_csv('China_Tech_HK.csv')

# %%
import matplotlib.pyplot as plt

# Assuming your data is in a DataFrame called df
# Calculate the correlation matrix
correlation_matrix = df.pivot_table(index='fecha', columns='ts_code', values='close', aggfunc='mean').corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='bone', interpolation='none', aspect='auto')
plt.colorbar()

# Set labels and title
plt.title('Correlación Heatmap de Precios de Stock')
plt.xticks(range(len(df['ts_code'].unique())), df['ts_code'].unique(), rotation=90)
plt.yticks(range(len(df['ts_code'].unique())), df['ts_code'].unique())

plt.style.use('miestilo.mplstyle')
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

plt.show()
plt.savefig('heatmap.png', transparent=False, facecolor='#2e3440')
